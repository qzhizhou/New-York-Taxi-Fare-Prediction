# %%
def clean(df):
    # Delimiter lats and lons to NY only
    df = df[(-76 <= df['pickup_longitude']) & (df['pickup_longitude'] <= -72)]
    df = df[(-76 <= df['dropoff_longitude']) & (df['dropoff_longitude'] <= -72)]
    df = df[(38 <= df['pickup_latitude']) & (df['pickup_latitude'] <= 42)]
    df = df[(38 <= df['dropoff_latitude']) & (df['dropoff_latitude'] <= 42)]
    # Remove possible outliers
    df = df[(0 < df['fare_amount']) & (df['fare_amount'] <= 250)]
    # Remove inconsistent values
    df = df[(df['dropoff_longitude'] != df['pickup_longitude'])]
    df = df[(df['dropoff_latitude'] != df['pickup_latitude'])]
    
    return df

# %%
def late_night (row):
    if (row['hour'] <= 6) or (row['hour'] >= 20):
        return 1
    else:
        return 0


def night (row):
    if ((row['hour'] <= 20) and (row['hour'] >= 16)) and (row['weekday'] < 5):
        return 1
    else:
        return 0
    
    
def manhattan(pickup_lat, pickup_long, dropoff_lat, dropoff_long):
    return np.abs(dropoff_lat - pickup_lat) + np.abs(dropoff_long - pickup_long)


def add_time_features(df):
    df['pickup_datetime'] =  pd.to_datetime(df['pickup_datetime'], format='%Y-%m-%d %H:%M:%S %Z')
    df['year'] = df['pickup_datetime'].apply(lambda x: x.year)
    df['month'] = df['pickup_datetime'].apply(lambda x: x.month)
    df['day'] = df['pickup_datetime'].apply(lambda x: x.day)
    df['hour'] = df['pickup_datetime'].apply(lambda x: x.hour)
    df['weekday'] = df['pickup_datetime'].apply(lambda x: x.weekday())
    df['pickup_datetime'] =  df['pickup_datetime'].apply(lambda x: str(x))
    df['night'] = df.apply (lambda x: night(x), axis=1)
    df['late_night'] = df.apply (lambda x: late_night(x), axis=1)
    # Drop 'pickup_datetime' as we won't need it anymore
    df = df.drop('pickup_datetime', axis=1)
    
    return df


def add_coordinate_features(df):
    lat1 = df['pickup_latitude']
    lat2 = df['dropoff_latitude']
    lon1 = df['pickup_longitude']
    lon2 = df['dropoff_longitude']
    
    # Add new features
    df['latdiff'] = (lat1 - lat2)
    df['londiff'] = (lon1 - lon2)

    return df


def add_distances_features(df):
    # Add distances from airpot and downtown
    ny = (-74.0063889, 40.7141667)
    jfk = (-73.7822222222, 40.6441666667)
    ewr = (-74.175, 40.69)
    lgr = (-73.87, 40.77)
    
    lat1 = df['pickup_latitude']
    lat2 = df['dropoff_latitude']
    lon1 = df['pickup_longitude']
    lon2 = df['dropoff_longitude']
    
    df['euclidean'] = (df['latdiff'] ** 2 + df['londiff'] ** 2) ** 0.5
    df['manhattan'] = manhattan(lat1, lon1, lat2, lon2)
    
    df['downtown_pickup_distance'] = manhattan(ny[1], ny[0], lat1, lon1)
    df['downtown_dropoff_distance'] = manhattan(ny[1], ny[0], lat2, lon2)
    df['jfk_pickup_distance'] = manhattan(jfk[1], jfk[0], lat1, lon1)
    df['jfk_dropoff_distance'] = manhattan(jfk[1], jfk[0], lat2, lon2)
    df['ewr_pickup_distance'] = manhattan(ewr[1], ewr[0], lat1, lon1)
    df['ewr_dropoff_distance'] = manhattan(ewr[1], ewr[0], lat2, lon2)
    df['lgr_pickup_distance'] = manhattan(lgr[1], lgr[0], lat1, lon1)
    df['lgr_dropoff_distance'] = manhattan(lgr[1], lgr[0], lat2, lon2)
    
    return df

# %%
def output_submission(raw_test, prediction, id_column, prediction_column, file_name):
    df = pd.DataFrame(prediction, columns=[prediction_column])
    df[id_column] = raw_test[id_column]
    df[[id_column, prediction_column]].to_csv((file_name), index=False)
    print('Output complete')
    
    
def plot_loss_accuracy(history):
    plt.figure(figsize=(20,10))
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper right')
    plt.show()

# %%
TRAIN_PATH = 'train.csv'
TEST_PATH = 'test.csv'
SUBMISSION_NAME = 'submission.csv'

# Model parameters
BATCH_SIZE = 256
EPOCHS = 50
LEARNING_RATE = 0.001
DATASET_SIZE = 6000000

# %%
import pandas as pd
# Load values in a more compact form
datatypes = {'key': 'str', 
              'fare_amount': 'float32',
              'pickup_datetime': 'str', 
              'pickup_longitude': 'float32',
              'pickup_latitude': 'float32',
              'dropoff_longitude': 'float32',
              'dropoff_latitude': 'float32',
              'passenger_count': 'uint8'}

# Only a fraction of the whole data
train = pd.read_csv(TRAIN_PATH, nrows=DATASET_SIZE, dtype=datatypes, usecols=[1,2,3,4,5,6])
test = pd.read_csv(TEST_PATH)

# %%
import numpy as np
train = clean(train)

train = add_time_features(train)
test = add_time_features(test)

add_coordinate_features(train)
add_coordinate_features(test)

train = add_distances_features(train)
test = add_distances_features(test)

train.head(5)
# Out:
#    fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0          4.5        -73.844315        40.721317         -73.841614
# 1         16.9        -74.016045        40.711304         -73.979271
# 2          5.7        -73.982735        40.761269         -73.991241
# 3          7.7        -73.987129        40.733143         -73.991570
# 4          5.3        -73.968094        40.768009         -73.956657
#
#    dropoff_latitude  year  month  day  hour  weekday          ...           \
# 0         40.712276  2009      6   15    17        0          ...
# 1         40.782005  2010      1    5    16        1          ...
# 2         40.750561  2011      8   18     0        3          ...
# 3         40.758091  2012      4   21     4        5          ...
# 4         40.783764  2010      3    9     7        1          ...
#
#    euclidean  manhattan  downtown_pickup_distance  downtown_dropoff_distance  \
# 0   0.009436   0.011742                  0.169225                   0.166665
# 1   0.079693   0.107475                  0.012519                   0.094957
# 2   0.013676   0.019215                  0.070756                   0.051542
# 3   0.025340   0.029388                  0.038236                   0.058744
# 4   0.019468   0.027191                  0.092138                   0.119329
#
#    jfk_pickup_distance  jfk_dropoff_distance  ewr_pickup_distance  \
# 0             0.139243              0.127501             0.362003
# 1             0.300959              0.334887             0.180259
# 2             0.317614              0.315413             0.263534
# 3             0.293883              0.323272             0.231014
# 4             0.309714              0.314032             0.284915
#
#    ewr_dropoff_distance  lgr_pickup_distance  lgr_dropoff_distance
# 0              0.355663             0.074368              0.086110
# 1              0.287734             0.204741              0.121276
# 2              0.244319             0.121466              0.140681
# 3              0.251521             0.153986              0.133479
# 4              0.312106             0.100085              0.100421
#
# [5 rows x 24 columns]

# %%
# Drop unwanted columns
dropped_columns = ['pickup_longitude', 'pickup_latitude', 
                   'dropoff_longitude', 'dropoff_latitude']
train_clean = train.drop(dropped_columns, axis=1)
test_clean = test.drop(dropped_columns + ['key', 'passenger_count'], axis=1)

# peek data
train_clean.head(5)
# Out:
#    fare_amount  year  month  day  hour  weekday  night  late_night   latdiff  \
# 0          4.5  2009      6   15    17        0      1           0  0.009041
# 1         16.9  2010      1    5    16        1      1           0 -0.070702
# 2          5.7  2011      8   18     0        3      0           1  0.010708
# 3          7.7  2012      4   21     4        5      0           1 -0.024948
# 4          5.3  2010      3    9     7        1      0           0 -0.015755
#
#     londiff  euclidean  manhattan  downtown_pickup_distance  \
# 0 -0.002701   0.009436   0.011742                  0.169225
# 1 -0.036774   0.079693   0.107475                  0.012519
# 2  0.008507   0.013676   0.019215                  0.070756
# 3  0.004440   0.025340   0.029388                  0.038236
# 4 -0.011436   0.019468   0.027191                  0.092138
#
#    downtown_dropoff_distance  jfk_pickup_distance  jfk_dropoff_distance  \
# 0                   0.166665             0.139243              0.127501
# 1                   0.094957             0.300959              0.334887
# 2                   0.051542             0.317614              0.315413
# 3                   0.058744             0.293883              0.323272
# 4                   0.119329             0.309714              0.314032
#
#    ewr_pickup_distance  ewr_dropoff_distance  lgr_pickup_distance  \
# 0             0.362003              0.355663             0.074368
# 1             0.180259              0.287734             0.204741
# 2             0.263534              0.244319             0.121466
# 3             0.231014              0.251521             0.153986
# 4             0.284915              0.312106             0.100085
#
#    lgr_dropoff_distance
# 0              0.086110
# 1              0.121276
# 2              0.140681
# 3              0.133479
# 4              0.100421

# %%
#from sklearn.cross_validation import train_test_split
from sklearn.model_selection import train_test_split
train_df, validation_df = train_test_split(train_clean, test_size=0.10, random_state=1)

# Get labels
train_labels = train_df['fare_amount'].values
validation_labels = validation_df['fare_amount'].values
train_df = train_df.drop(['fare_amount'], axis=1)
validation_df = validation_df.drop(['fare_amount'], axis=1)

# %%
from sklearn import preprocessing
# Scale data
# Note: im doing this here with sklearn scaler but, on the Coursera code the scaling is done with Dataflow and Tensorflow
scaler = preprocessing.MinMaxScaler()
train_df_scaled = scaler.fit_transform(train_df)
validation_df_scaled = scaler.transform(validation_df)
test_scaled = scaler.transform(test_clean)
# Out:
# C:\Users\tty81\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:323: DataConversionWarning: Data with input dtype float32, int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %%
from keras.models import Sequential
from keras.layers import Activation, Dense
from keras import optimizers,regularizers
from keras.layers.normalization import BatchNormalization

model = Sequential()
model.add(Dense(256, activation='relu', input_dim=train_df_scaled.shape[1], activity_regularizer=regularizers.l1(0.01)))
model.add(BatchNormalization())
model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(64, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(32, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(8, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1))

adam = optimizers.adam(lr=LEARNING_RATE)
model.compile(loss='mse', optimizer=adam, metrics=['mae'])
# Out:
# WARNING:tensorflow:From C:\Users\tty81\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 256)               5120
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64)                256
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                2080
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 32)                128
# _________________________________________________________________
# dense_5 (Dense)              (None, 8)                 264
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8)                 32
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 50,577
# Trainable params: 49,601
# Non-trainable params: 976
# _________________________________________________________________

# %%
history = model.fit(x=train_df_scaled, y=train_labels, batch_size=BATCH_SIZE, epochs=EPOCHS, 
                    verbose=1, validation_data=(validation_df_scaled, validation_labels), 
                    shuffle=True)
# Out:
# WARNING:tensorflow:From C:\Users\tty81\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 5225686 samples, validate on 580632 samples
# Epoch 1/50
# 5225686/5225686 [==============================] - 165s 31us/step - loss: 19.5360 - mean_absolute_error: 2.2845 - val_loss: 202.7662 - val_mean_absolute_error: 13.5266
# Epoch 2/50
# 5225686/5225686 [==============================] - 154s 29us/step - loss: 15.6039 - mean_absolute_error: 2.0012 - val_loss: 24.2411 - val_mean_absolute_error: 3.2472
# Epoch 3/50
# 5225686/5225686 [==============================] - 154s 29us/step - loss: 15.4948 - mean_absolute_error: 1.9884 - val_loss: 21.1852 - val_mean_absolute_error: 3.1087
# Epoch 4/50
# 5225686/5225686 [==============================] - 153s 29us/step - loss: 15.4204 - mean_absolute_error: 1.9816 - val_loss: 16.8310 - val_mean_absolute_error: 1.9939
# Epoch 5/50
# 5225686/5225686 [==============================] - 154s 29us/step - loss: 15.4152 - mean_absolute_error: 1.9771 - val_loss: 15.6503 - val_mean_absolute_error: 1.9451
# Epoch 6/50
# 5225686/5225686 [==============================] - 153s 29us/step - loss: 15.7246 - mean_absolute_error: 2.0214 - val_loss: 53.6892 - val_mean_absolute_error: 5.1878
# Epoch 7/50
# 5225686/5225686 [==============================] - 154s 29us/step - loss: 15.7573 - mean_absolute_error: 2.0380 - val_loss: 103.3401 - val_mean_absolute_error: 7.8073
# Epoch 8/50
# 5225686/5225686 [==============================] - 154s 29us/step - loss: 15.7058 - mean_absolute_error: 2.0317 - val_loss: 34.2915 - val_mean_absolute_error: 4.4244
# Epoch 9/50
# 5225686/5225686 [==============================] - 154s 29us/step - loss: 15.6658 - mean_absolute_error: 2.0298 - val_loss: 36.3057 - val_mean_absolute_error: 4.9025
# Epoch 10/50
# 5225686/5225686 [==============================] - 154s 29us/step - loss: 15.6382 - mean_absolute_error: 2.0284 - val_loss: 17.8895 - val_mean_absolute_error: 1.9573
# Epoch 11/50
# 5225686/5225686 [==============================] - 155s 30us/step - loss: 15.6301 - mean_absolute_error: 2.0261 - val_loss: 24.3485 - val_mean_absolute_error: 3.1756
# Epoch 12/50
# 5225686/5225686 [==============================] - 155s 30us/step - loss: 15.6017 - mean_absolute_error: 2.0242 - val_loss: 17.2051 - val_mean_absolute_error: 2.0494
# Epoch 13/50
# 5225686/5225686 [==============================] - 156s 30us/step - loss: 15.5933 - mean_absolute_error: 2.0238 - val_loss: 38.4071 - val_mean_absolute_error: 5.1254
# Epoch 14/50
# 5225686/5225686 [==============================] - 156s 30us/step - loss: 15.5872 - mean_absolute_error: 2.0234 - val_loss: 18.5249 - val_mean_absolute_error: 2.2258
# Epoch 15/50
# 5225686/5225686 [==============================] - 155s 30us/step - loss: 15.5452 - mean_absolute_error: 2.0214 - val_loss: 18.7848 - val_mean_absolute_error: 2.7868
# Epoch 16/50
# 5225686/5225686 [==============================] - 154s 29us/step - loss: 15.5603 - mean_absolute_error: 2.0220 - val_loss: 18.2141 - val_mean_absolute_error: 2.7777
# Epoch 17/50
# 5225686/5225686 [==============================] - 154s 29us/step - loss: 15.5562 - mean_absolute_error: 2.0191 - val_loss: 18.3457 - val_mean_absolute_error: 2.2124
# Epoch 18/50
# 5225686/5225686 [==============================] - 154s 29us/step - loss: 15.5147 - mean_absolute_error: 2.0169 - val_loss: 20.7949 - val_mean_absolute_error: 3.2157
# Epoch 19/50
# 5225686/5225686 [==============================] - 155s 30us/step - loss: 15.5243 - mean_absolute_error: 2.0171 - val_loss: 18.8989 - val_mean_absolute_error: 2.7652
# Epoch 20/50
# 5225686/5225686 [==============================] - 155s 30us/step - loss: 15.5234 - mean_absolute_error: 2.0171 - val_loss: 18.0356 - val_mean_absolute_error: 2.1668
# Epoch 21/50
# 5225686/5225686 [==============================] - 155s 30us/step - loss: 15.5363 - mean_absolute_error: 2.0181 - val_loss: 19.0980 - val_mean_absolute_error: 2.2329
# Epoch 22/50
# 5225686/5225686 [==============================] - 155s 30us/step - loss: 15.5129 - mean_absolute_error: 2.0157 - val_loss: 18.4379 - val_mean_absolute_error: 2.2304
# Epoch 23/50
# 5225686/5225686 [==============================] - 155s 30us/step - loss: 15.4868 - mean_absolute_error: 2.0152 - val_loss: 20.1871 - val_mean_absolute_error: 2.4140
# Epoch 24/50
# 5225686/5225686 [==============================] - 155s 30us/step - loss: 15.4791 - mean_absolute_error: 2.0141 - val_loss: 54.2355 - val_mean_absolute_error: 5.6448
# Epoch 25/50
# 5225686/5225686 [==============================] - 155s 30us/step - loss: 15.5072 - mean_absolute_error: 2.0125 - val_loss: 16.2672 - val_mean_absolute_error: 2.0297
# Epoch 26/50
# 5225686/5225686 [==============================] - 155s 30us/step - loss: 15.4616 - mean_absolute_error: 2.0128 - val_loss: 25.4698 - val_mean_absolute_error: 3.1706
# Epoch 27/50
# 5225686/5225686 [==============================] - 155s 30us/step - loss: 15.4372 - mean_absolute_error: 2.0120 - val_loss: 76.0401 - val_mean_absolute_error: 5.9517
# Epoch 28/50
# 5225686/5225686 [==============================] - 155s 30us/step - loss: 15.4310 - mean_absolute_error: 2.0109 - val_loss: 100.8757 - val_mean_absolute_error: 5.2530
# Epoch 29/50
# 5225686/5225686 [==============================] - 156s 30us/step - loss: 15.4357 - mean_absolute_error: 2.0099 - val_loss: 23.2048 - val_mean_absolute_error: 2.5094
# Epoch 30/50
# 5225686/5225686 [==============================] - 156s 30us/step - loss: 15.4106 - mean_absolute_error: 2.0120 - val_loss: 21.5785 - val_mean_absolute_error: 2.6905
# Epoch 31/50
# 5225686/5225686 [==============================] - 157s 30us/step - loss: 15.4052 - mean_absolute_error: 2.0127 - val_loss: 24.3207 - val_mean_absolute_error: 3.3945
# Epoch 32/50
# 5225686/5225686 [==============================] - 155s 30us/step - loss: 15.3908 - mean_absolute_error: 2.0127 - val_loss: 17.8802 - val_mean_absolute_error: 2.2369
# Epoch 33/50
# 5225686/5225686 [==============================] - 155s 30us/step - loss: 15.3703 - mean_absolute_error: 2.0120 - val_loss: 16.2835 - val_mean_absolute_error: 2.1796
# Epoch 34/50
# 5225686/5225686 [==============================] - 156s 30us/step - loss: 15.4022 - mean_absolute_error: 2.0096 - val_loss: 15.8609 - val_mean_absolute_error: 1.9818
# Epoch 35/50
# 5225686/5225686 [==============================] - 156s 30us/step - loss: 15.3489 - mean_absolute_error: 2.0099 - val_loss: 82.1219 - val_mean_absolute_error: 8.3893
# Epoch 36/50
# 5225686/5225686 [==============================] - 156s 30us/step - loss: 15.3575 - mean_absolute_error: 2.0099 - val_loss: 25.7146 - val_mean_absolute_error: 3.9191
# Epoch 37/50
# 5225686/5225686 [==============================] - 155s 30us/step - loss: 15.3571 - mean_absolute_error: 2.0115 - val_loss: 26.4958 - val_mean_absolute_error: 4.0027
# Epoch 38/50
# 5225686/5225686 [==============================] - 155s 30us/step - loss: 15.3619 - mean_absolute_error: 2.0098 - val_loss: 119.9570 - val_mean_absolute_error: 9.9545
# Epoch 39/50
# 5225686/5225686 [==============================] - 155s 30us/step - loss: 15.3069 - mean_absolute_error: 2.0098 - val_loss: 30.4028 - val_mean_absolute_error: 3.4440
# Epoch 40/50
# 5225686/5225686 [==============================] - 155s 30us/step - loss: 15.2973 - mean_absolute_error: 2.0079 - val_loss: 31.5177 - val_mean_absolute_error: 3.9451
# Epoch 41/50
# 5225686/5225686 [==============================] - 155s 30us/step - loss: 15.3239 - mean_absolute_error: 2.0077 - val_loss: 33.1369 - val_mean_absolute_error: 4.6061
# Epoch 42/50
# 5225686/5225686 [==============================] - 155s 30us/step - loss: 15.3035 - mean_absolute_error: 2.0076 - val_loss: 28.1813 - val_mean_absolute_error: 2.8043
# Epoch 43/50
# 5225686/5225686 [==============================] - 155s 30us/step - loss: 15.2677 - mean_absolute_error: 2.0059 - val_loss: 23.5129 - val_mean_absolute_error: 2.0150
# Epoch 44/50
# 5225686/5225686 [==============================] - 155s 30us/step - loss: 15.2466 - mean_absolute_error: 2.0086 - val_loss: 20.2148 - val_mean_absolute_error: 2.0753
# Epoch 45/50
# 5225686/5225686 [==============================] - 153s 29us/step - loss: 15.2338 - mean_absolute_error: 2.0066 - val_loss: 29.9570 - val_mean_absolute_error: 2.6359
# Epoch 46/50
# 5225686/5225686 [==============================] - 153s 29us/step - loss: 15.1865 - mean_absolute_error: 2.0063 - val_loss: 56.8458 - val_mean_absolute_error: 2.0725
# Epoch 47/50
# 5225686/5225686 [==============================] - 152s 29us/step - loss: 15.1310 - mean_absolute_error: 2.0050 - val_loss: 52.9429 - val_mean_absolute_error: 2.1002
# Epoch 48/50
# 5225686/5225686 [==============================] - 153s 29us/step - loss: 15.1543 - mean_absolute_error: 2.0045 - val_loss: 21.0281 - val_mean_absolute_error: 2.0804
# Epoch 49/50
# 5225686/5225686 [==============================] - 152s 29us/step - loss: 14.9931 - mean_absolute_error: 1.9996 - val_loss: 19.4886 - val_mean_absolute_error: 2.3565
# Epoch 50/50
# 5225686/5225686 [==============================] - 152s 29us/step - loss: 15.0118 - mean_absolute_error: 2.0011 - val_loss: 20.1009 - val_mean_absolute_error: 2.3096

# %%
import matplotlib.pyplot as plt

plot_loss_accuracy(history)

# %%
# Make prediction
prediction = model.predict(test_scaled, batch_size=128, verbose=1)
# Out:
# 9914/9914 [==============================] - 0s 31us/step

# %%
# output prediction
output_submission(test, prediction, 'key', 'fare_amount', SUBMISSION_NAME)
# Out:
# Output complete

# %%
model.save('nytaxi.h5')
